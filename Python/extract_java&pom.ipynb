# %%
import os

path = 'D:\\python\\project_jar\\'

arr = os.listdir(path)
all_file = []
for folder in arr:
    files = []
    # r=root, d=directories, f = files
    dir_path = path + folder
    for r, d, f in os.walk(dir_path):
        for file in f:
            if '.java' in file:
                    files.append(os.path.join(r, file))
    all_file.append(files)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\os.py:367, in _walk(top, topdown, onerror, followlinks)
#     366 try:
# --> 367     entry = next(scandir_it)
#     368 except StopIteration:
#
# StopIteration:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [89], in <cell line: 7>()
#       9 # r=root, d=directories, f = files
#      10 dir_path = path + folder
# ---> 11 for r, d, f in os.walk(dir_path):
#      12     for file in f:
#      13         if '.java' in file:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\os.py:418, in _walk(top, topdown, onerror, followlinks)
#     413         # Issue #23605: os.path.islink() is used instead of caching
# ...

# %%
len(all_file)
# Out:
# 613

# %%
# Making folders

import os

# Directory
directory = "project"
  
# Parent Directory path
parent_dir = "D:\\python\\"
  
# Path
path = os.path.join(parent_dir, directory)
  
# Create the directory
# 'GeeksForGeeks' in
# '/home / User / Documents'
os.mkdir(path)
print("Directory '% s' created" % directory)


path = 'D:\\python\\project_jar\\'

arr = os.listdir(path)
all_file = []
for folder in arr:
    directory = folder 
    parent_dir = "D:\\python\\project"
    path = os.path.join(parent_dir, directory)
    os.mkdir(path)
# Out:
# Directory 'project' created

# %%
path = 'D:\\python\\content\\'

arr = os.listdir(path)
all_file = []
for folder in arr:
    files = []
    # r=root, d=directories, f = files
    dir_path = path + folder
    for r, d, f in os.walk(dir_path):
        for file in f:
            if '.java' in file:
                    files.append(os.path.join(r, file))
    all_file.append(files)

# %%
import shutil

path = 'D:\\python\\project_jar\\'
copyPath = 'D:\\python\\project\\'

arr = os.listdir(path)
for folder in arr:
    dir_path = os.path.join(path, folder)
    for r, d, f in os.walk(dir_path):
        for file in f:
            if '.java' in file:
                    shutil.copy(os.path.join(r, file), os.path.join(copyPath, folder))

# %%
len(all_file[1])

# %%
import shutil

shutil.copy("D:\\python\\codeoooo.py", "D:\\python\\New")
# Out:
# 'D:\\python\\New\\codeoooo.py'

# %%
import xml.etree.ElementTree as ET


tree = ET.parse('D:\\python\\application_2022_7.541.24.xml')
root = tree.getroot()

# %%
for neighbor in root[6].iter('{http://maven.apache.org/POM/4.0.0}groupId'):
    print(neighbor.attrib)
# Out:
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}

# %%
[elem.tag for elem in root.iter()]
# Out:
# ['{http://maven.apache.org/POM/4.0.0}project',
#  '{http://maven.apache.org/POM/4.0.0}modelVersion',
#  '{http://maven.apache.org/POM/4.0.0}parent',
#  '{http://maven.apache.org/POM/4.0.0}groupId',
#  '{http://maven.apache.org/POM/4.0.0}artifactId',
#  '{http://maven.apache.org/POM/4.0.0}version',
#  '{http://maven.apache.org/POM/4.0.0}relativePath',
#  '{http://maven.apache.org/POM/4.0.0}artifactId',
#  '{http://maven.apache.org/POM/4.0.0}packaging',
#  '{http://maven.apache.org/POM/4.0.0}version',
#  '{http://maven.apache.org/POM/4.0.0}description',
#  '{http://maven.apache.org/POM/4.0.0}dependencies',
#  '{http://maven.apache.org/POM/4.0.0}dependency',
#  '{http://maven.apache.org/POM/4.0.0}groupId',
#  '{http://maven.apache.org/POM/4.0.0}artifactId',
#  '{http://maven.apache.org/POM/4.0.0}version',
#  '{http://maven.apache.org/POM/4.0.0}dependency',
#  '{http://maven.apache.org/POM/4.0.0}groupId',
#  '{http://maven.apache.org/POM/4.0.0}artifactId',
# ...

# %%
for movie in root.iter('{http://maven.apache.org/POM/4.0.0}dependency'):
    print(movie.tag)
# Out:
# {http://maven.apache.org/POM/4.0.0}dependency
# {http://maven.apache.org/POM/4.0.0}dependency
# {http://maven.apache.org/POM/4.0.0}dependency
# {http://maven.apache.org/POM/4.0.0}dependency
# {http://maven.apache.org/POM/4.0.0}dependency
# {http://maven.apache.org/POM/4.0.0}dependency
# {http://maven.apache.org/POM/4.0.0}dependency
# {http://maven.apache.org/POM/4.0.0}dependency
# {http://maven.apache.org/POM/4.0.0}dependency
# {http://maven.apache.org/POM/4.0.0}dependency
# {http://maven.apache.org/POM/4.0.0}dependency
# {http://maven.apache.org/POM/4.0.0}dependency
# {http://maven.apache.org/POM/4.0.0}dependency
# {http://maven.apache.org/POM/4.0.0}dependency
# {http://maven.apache.org/POM/4.0.0}dependency
# {http://maven.apache.org/POM/4.0.0}dependency
# {http://maven.apache.org/POM/4.0.0}dependency
# {http://maven.apache.org/POM/4.0.0}dependency
# {http://maven.apache.org/POM/4.0.0}dependency
# {http://maven.apache.org/POM/4.0.0}dependency
# ...

# %%
# from lxml import etree
from collections import defaultdict
import os
import xml.etree.ElementTree as etree


f = 0
v=0


    
path1 = 'D:\\python\\pom'

arr = os.listdir(path1)

for i in arr:
    
#     print("hi")
    pomPath =os.path.join(path1, i)
#     print(pomPath)
    root = etree.parse(pomPath)
    tree = etree.ElementTree(root)

#         depend = tree.xpath("//*[local-name()='dependency']")
#         dependencyInfo = defaultdict(dict)

#         for dep in depend:
#             infoList = []
#             for child in dep.getchildren():
#                 infoList.append(child.tag.split('}')[1])
#                 infoList.append(child.text)

        
#         try:
#             dependencyInfo[infoList[1]].update({infoList[2] : infoList[3],infoList[4] : infoList[5]})
#         except:
#             v = v+1


print(f)
print(v)
# Out:
# 0
# 0

# %%
len(arr)
# Out:
# 2986

# %%
import os

path = 'D:\\python\\project_jar\\'

arr = os.listdir(path)

for i in arr:
    print(os.path.join(path, i))
# Out:
# D:\python\project_jar\aliyun-java-sdk-core_2015_2.0.0-rc1
# D:\python\project_jar\aliyun-java-sdk-core_2015_2.0.0-rc2
# D:\python\project_jar\aliyun-java-sdk-core_2015_2.0.2-rc1
# D:\python\project_jar\aliyun-java-sdk-core_2015_2.1.0
# D:\python\project_jar\aliyun-java-sdk-core_2015_2.1.1
# D:\python\project_jar\aliyun-java-sdk-core_2015_2.1.2
# D:\python\project_jar\aliyun-java-sdk-core_2015_2.1.3
# D:\python\project_jar\aliyun-java-sdk-core_2015_2.1.4
# D:\python\project_jar\aliyun-java-sdk-core_2015_2.1.5
# D:\python\project_jar\aliyun-java-sdk-core_2015_2.1.6
# D:\python\project_jar\aliyun-java-sdk-core_2015_2.1.7
# D:\python\project_jar\aliyun-java-sdk-core_2015_2.1.8
# D:\python\project_jar\aliyun-java-sdk-core_2015_2.1.9
# D:\python\project_jar\aliyun-java-sdk-core_2015_2.2.0
# D:\python\project_jar\aliyun-java-sdk-core_2015_2.2.1
# D:\python\project_jar\aliyun-java-sdk-core_2015_2.2.2
# D:\python\project_jar\aliyun-java-sdk-core_2015_2.2.3
# ...

# %%
from collections import defaultdict
import os
import xml.etree.ElementTree as etree


f = 0
v=0


    
path2 = 'D:\\python\\pom1'

arr = os.listdir(path2)
dependencies = []
for i in arr:
#     print("------")
    f = f +1
    pomPath =os.path.join(path2, i)
    root = etree.parse(pomPath)
#     print(i)
    tree = etree.ElementTree(root)
    h = 0
    for book in root.findall('{http://maven.apache.org/POM/4.0.0}dependencies'):
        v = v + 1
#         print(pomPath)
        g=0
        dependency = ""
        for d in book.findall('{http://maven.apache.org/POM/4.0.0}dependency'):
            g=g+1
            b=0;
#             name = d.find('{http://maven.apache.org/POM/4.0.0}groupId').text
            
            name = d.find('{http://maven.apache.org/POM/4.0.0}artifactId').text
            try:
                version = d.find('{http://maven.apache.org/POM/4.0.0}version').text
                dependency = dependency + name+version + "#"
            except:
                b = b+1
#     print(dependency)
    dependencies.append({"name": i , "libraries" : dependency})
#                 print(pomPath)
#         print("2 " + str(g))

dependencies
# Out:
# [{'name': 'micrometer-core_2017_0.10.0.RELEASE.xml',
#   'libraries': 'spectator-api0.57.1#simpleclient_common0.0.26#java-dogstatsd-client2.3#metrics-core3.2.4#spectator-reg-atlas0.57.1#metrics-graphite3.2.4#metrics-ganglia3.2.4#guava21.0#caffeine2.3.0#logback-classic1.2.3#reactor-core3.1.0.BUILD-SNAPSHOT#'},
#  {'name': 'micrometer-core_2017_0.11.0.RELEASE.xml',
#   'libraries': 'spectator-api0.57.1#metrics-core3.2.4#guava21.0#caffeine2.3.0#logback-classic1.2.3#reactor-core3.1.0.BUILD-SNAPSHOT#'},
#  {'name': 'micrometer-core_2017_0.12.0.RELEASE.xml',
#   'libraries': 'spectator-api0.57.1#metrics-core3.2.4#guava21.0#caffeine2.3.0#logback-classic1.2.3#reactor-core3.1.0.BUILD-SNAPSHOT#'},
#  {'name': 'micrometer-core_2017_0.6.3.RELEASE.xml',
#   'libraries': 'spectator-api0.56.0#simpleclient0.0.25#simpleclient_pushgateway0.0.25#java-dogstatsd-client2.3#metrics-core3.2.3#spectator-reg-atlas0.56.0#guava21.0#logback-classic1.2.3#reactor-core3.1.0.BUILD-SNAPSHOT#'},
# ...

# %%
with open('test.txt', 'w') as f:
    for s in dependencies:
        f.write(s["name"] + "," + s["libraries"])

# %%
with open('test.txt') as f:
    lines = f.readlines()
    
each = str(lines).split(",")
for e in each:
        lib = e.split("#")
        for l in lib:
            print(l)
# Out:
# ['micrometer-core_2021_1.5.15.xml
# HdrHistogram2.1.12
# LatencyUtils2.0.3
# jsr3053.0.2
# metrics-core4.0.7
# guava29.0-jre
# caffeine2.8.2
# ehcache2.10.6
# cache-api1.1.1
# hazelcast4.0.1
# hibernate-entitymanager6.0.0.Alpha5
# jetty-server9.4.28.v20200408
# jetty-client9.4.28.v20200408
# tomcat-embed-core8.5.54
# httpclient4.5.12
# httpasyncclient4.1.4
# hystrix-core1.5.12
# logback-classic1.2.3
# log4j-core2.13.2
# reactor-core3.3.18.RELEASE
# reactor-netty0.9.21.RELEASE
# aspectjweaver1.8.14
# okhttp4.5.0
# mongo-java-driver3.12.3
# jooq3.13.1
# kafka-clients2.5.0
# kafka-streams2.5.0
# micrometer-core_2021_1.5.16.xml
# HdrHistogram2.1.12
# LatencyUtils2.0.3
# jsr3053.0.2
# metrics-core4.0.7
# guava29.0-jre
# caffeine2.8.2
# ehcache2.10.6
# cache-api1.1.1
# hazelcast4.0.1
# hibernate-entitymanager6.0.0.Alpha5
# jetty-server9.4.28.v20200408
# jetty-client9.4.28.v20200408
# tomcat-embed-core8.5.54
# httpclient4.5.12
# httpasyncclient4.1.4
# hystrix-core1.5.12
# ...
