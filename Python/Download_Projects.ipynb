# %%
list_of_categories = [
    'https://search.maven.org/solrsearch/select?q=g:org.codehaus.cargo+AND+a:cargo-core-uberjar&core=gav&rows=200&wt=json',
    'https://search.maven.org/solrsearch/select?q=g:org.glassfish.main.extras+AND+a:glassfish-embedded-all&core=gav&rows=200&wt=json',
    'https://search.maven.org/solrsearch/select?q=g:us.fatehi+AND+a:schemacrawler&core=gav&rows=200&wt=json',
    'https://search.maven.org/solrsearch/select?q=g:io.ultreia.java4all.http+AND+a:http-api&core=gav&rows=200&wt=json',
    'https://search.maven.org/solrsearch/select?q=g:io.ultreia.java4all.topia+AND+a:templates&core=gav&rows=200&wt=json',
    'https://search.maven.org/solrsearch/select?q=g:io.github.astrapi69+AND+a:gson-extensions&core=gav&rows=200&wt=json',
    'https://search.maven.org/solrsearch/select?q=g:berlin.yuna+AND+a:nats-server-embedded&core=gav&rows=200&wt=json',
    'https://search.maven.org/solrsearch/select?q=g:org.influxdb+AND+a:influxdb-java&core=gav&rows=200&wt=json',
    'https://search.maven.org/solrsearch/select?q=g:com.konghq+AND+a:unirest-java&core=gav&rows=200&wt=json',
    'https://search.maven.org/solrsearch/select?q=g:com.jcabi+AND+a:jcabi-http&core=gav&rows=200&wt=json',
    'https://search.maven.org/solrsearch/select?q=g:net.serenity-bdd+AND+a:serenity-model&core=gav&rows=200&wt=json',
    'https://search.maven.org/solrsearch/select?q=g:com.github.tomakehurst+AND+a:wiremock-jre8&core=gav&rows=200&wt=json',
    'https://search.maven.org/solrsearch/select?q=g:net.sourceforge.htmlunit+AND+a:htmlunit8&core=gav&rows=200&wt=json',
    'https://search.maven.org/solrsearch/select?q=g:io.swagger+AND+a:swagger-core&core=gav&rows=200&wt=json',
    'https://search.maven.org/solrsearch/select?q=g:com.github.ben-manes.caffeine+AND+a:guava&core=gav&rows=200&wt=json',
    'https://search.maven.org/solrsearch/select?q=g:io.micrometer+AND+a:micrometer-core&core=gav&rows=200&wt=json',
    'https://search.maven.org/solrsearch/select?q=g:io.rest-assured+AND+a:rest-assured&core=gav&rows=200&wt=json',
    'https://search.maven.org/solrsearch/select?q=g:com.rabbitmq+AND+a:amqp-client&core=gav&rows=200&wt=json',
    'https://search.maven.org/solrsearch/select?q=g:com.yahoo.vespa+AND+a:application&core=gav&rows=200&wt=json',
    'https://search.maven.org/solrsearch/select?q=g:org.apache.tika+AND+a:tika-parser-xml-module&core=gav&rows=200&wt=json',
    'https://search.maven.org/solrsearch/select?q=g:org.codehaus.modello+AND+a:modello-plugin-xsd&core=gav&rows=200&wt=json',
    'https://search.maven.org/solrsearch/select?q=g:com.aliyun+AND+a:aliyun-java-sdk-core&core=gav&rows=200&wt=json',
    'https://search.maven.org/solrsearch/select?q=g:org.springframework.boot+AND+a:spring-boot-starter-data-jpa&core=gav&rows=200&wt=json',
    'https://search.maven.org/solrsearch/select?q=g:org.springframework.security+AND+a:spring-security-config&core=gav&rows=200&wt=json',
    'https://search.maven.org/solrsearch/select?q=g:org.primefaces+AND+a:primefaces&core=gav&rows=200&wt=json',
    'https://search.maven.org/solrsearch/select?q=g:com.sqlapp+AND+a:sqlapp-core&core=gav&rows=200&wt=json',
    'https://search.maven.org/solrsearch/select?q=g:com.hack23.cia+AND+a:testfoundation&core=gav&rows=200&wt=json',
    'https://search.maven.org/solrsearch/select?q=g:ognl+AND+a:ognl&core=gav&rows=200&wt=json',
    'https://search.maven.org/solrsearch/select?q=g:com.puppycrawl.tools+AND+a:checkstyle&core=gav&rows=200&wt=json',
    'https://search.maven.org/solrsearch/select?q=g:com.github.javaparser+AND+a:javaparser-symbol-solver-core&core=gav&rows=200&wt=json',
    'https://search.maven.org/solrsearch/select?q=g:com.github.618lf+AND+a:swak-core&core=gav&rows=200&wt=json',
    'https://search.maven.org/solrsearch/select?q=g:org.mybatis+AND+a:mybatis&core=gav&rows=200&wt=json',
    'https://search.maven.org/solrsearch/select?q=g:org.apache.jackrabbit+AND+a:jackrabbit-jcr-commons&core=gav&rows=200&wt=json',
    'https://search.maven.org/solrsearch/select?q=g:com.querydsl+AND+a:querydsl-jpa&core=gav&rows=200&wt=json',
    'https://search.maven.org/solrsearch/select?q=g:org.rocksdb+AND+a:rocksdbjni&core=gav&rows=200&wt=json',
    'https://search.maven.org/solrsearch/select?q=g:p6spy+AND+a:p6spy&core=gav&rows=200&wt=json',
    'https://search.maven.org/solrsearch/select?q=g:com.alibaba+AND+a:druid&core=gav&rows=200&wt=json',
    'https://search.maven.org/solrsearch/select?q=g:org.springframework.cloud+AND+a:spring-cloud-spring-service-connector&core=gav&rows=200&wt=json',
    'https://search.maven.org/solrsearch/select?q=g:org.apache.calcite+AND+a:calcite-core&core=gav&rows=200&wt=json',
    'https://search.maven.org/solrsearch/select?q=g:org.opencms+AND+a:opencms-core&core=gav&rows=200&wt=json'


    
]

# %%
len(list_of_categories)
# Out:
# 40

# %%
list_of_download = [
    'https://repo1.maven.org/maven2/org/codehaus/cargo/cargo-core-uberjar/',
    'https://repo1.maven.org/maven2/org/glassfish/main/extras/glassfish-embedded-all/',
    'https://repo1.maven.org/maven2/us/fatehi/schemacrawler/',
    'https://repo1.maven.org/maven2/io/ultreia/java4all/http/http-api/',
    'https://repo1.maven.org/maven2/io/ultreia/java4all/topia/templates/',
    'https://repo1.maven.org/maven2/io/github/astrapi69/gson-extensions/',
    'https://repo1.maven.org/maven2/berlin/yuna/nats-server-embedded/',
    'https://repo1.maven.org/maven2/org/influxdb/influxdb-java/',
    'https://repo1.maven.org/maven2/com/konghq/unirest-java/',
    'https://repo1.maven.org/maven2/com/jcabi/jcabi-http/',
    'https://repo1.maven.org/maven2/net/serenity-bdd/serenity-model/',
    'https://repo1.maven.org/maven2/com/github/tomakehurst/wiremock-jre8/',
    'https://repo1.maven.org/maven2/net/sourceforge/htmlunit/htmlunit/',
    'https://repo1.maven.org/maven2/io/swagger/swagger-core/',
    'https://repo1.maven.org/maven2/com/github/ben-manes/caffeine/guava/',
    'https://repo1.maven.org/maven2/io/micrometer/micrometer-core/',
    'https://repo1.maven.org/maven2/io/rest-assured/rest-assured/',
    'https://repo1.maven.org/maven2/com/rabbitmq/amqp-client/',
    'https://repo1.maven.org/maven2/com/yahoo/vespa/application/',
    'https://repo1.maven.org/maven2/org/apache/tika/tika-parser-xml-module/',
    'https://repo1.maven.org/maven2/org/codehaus/modello/modello-plugin-xsd/',
    'https://repo1.maven.org/maven2/com/aliyun/aliyun-java-sdk-core/',
    'https://repo1.maven.org/maven2/org/springframework/boot/spring-boot-starter-data-jpa/',
    'https://repo1.maven.org/maven2/org/springframework/security/spring-security-config/',
    'https://repo1.maven.org/maven2/org/primefaces/primefaces/',
    'https://repo1.maven.org/maven2/com/sqlapp/sqlapp-core/',
    'https://repo1.maven.org/maven2/com/hack23/cia/testfoundation/',
    'https://repo1.maven.org/maven2/ognl/ognl/',
    'https://repo1.maven.org/maven2/com/puppycrawl/tools/checkstyle/',
    'https://repo1.maven.org/maven2/com/github/javaparser/javaparser-symbol-solver-core/',
    'https://repo1.maven.org/maven2/com/github/618lf/swak-core/',
    'https://repo1.maven.org/maven2/org/mybatis/mybatis/',
    'https://repo1.maven.org/maven2/org/apache/jackrabbit/jackrabbit-jcr-commons/',
    'https://repo1.maven.org/maven2/com/querydsl/querydsl-jpa/',
    'https://repo1.maven.org/maven2/org/rocksdb/rocksdbjni/',
    'https://repo1.maven.org/maven2/p6spy/p6spy/',
    'https://repo1.maven.org/maven2/com/alibaba/druid/',
    'https://repo1.maven.org/maven2/org/springframework/cloud/spring-cloud-spring-service-connector/',
    'https://repo1.maven.org/maven2/org/apache/calcite/calcite-core/',
    'https://repo1.maven.org/maven2/org/opencms/opencms-core/'
    
]

# %%
import json
import requests
from datetime import datetime, timezone

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.84 Safari/537.36',
}
i = 0
library_list = []
for li in list_of_categories:
  page = requests.get(li, headers=headers)
  x = page.content
  y = json.loads(x)
  for x in y["response"]["docs"]:
    dt_object = datetime.fromtimestamp(int(x["timestamp"])/1000)
    library_list.append({"link" : list_of_download[i] + x["v"], "year" : dt_object.year , "name" : x["a"], "version": x["v"]})
  i = i+1
print(library_list)
# Out:
# [{'link': 'https://repo1.maven.org/maven2/org/codehaus/cargo/cargo-core-uberjar/1.9.11', 'year': 2022, 'name': 'cargo-core-uberjar', 'version': '1.9.11'}, {'link': 'https://repo1.maven.org/maven2/org/codehaus/cargo/cargo-core-uberjar/1.9.10', 'year': 2022, 'name': 'cargo-core-uberjar', 'version': '1.9.10'}, {'link': 'https://repo1.maven.org/maven2/org/codehaus/cargo/cargo-core-uberjar/1.9.9', 'year': 2021, 'name': 'cargo-core-uberjar', 'version': '1.9.9'}, {'link': 'https://repo1.maven.org/maven2/org/codehaus/cargo/cargo-core-uberjar/1.9.8', 'year': 2021, 'name': 'cargo-core-uberjar', 'version': '1.9.8'}, {'link': 'https://repo1.maven.org/maven2/org/codehaus/cargo/cargo-core-uberjar/1.9.7', 'year': 2021, 'name': 'cargo-core-uberjar', 'version': '1.9.7'}, {'link': 'https://repo1.maven.org/maven2/org/codehaus/cargo/cargo-core-uberjar/1.9.6', 'year': 2021, 'name': 'cargo-core-uberjar', 'version': '1.9.6'}, {'link': 'https://repo1.maven.org/maven2/org/codehaus/cargo/cargo-core-uberjar/1.
# ...

# %%
for link in library_list:
  links = requests.get(link["link"], headers=headers)
  # print(link["link"])
  from lxml import html
  files_tree = html.fromstring(links.content)
  all_links = files_tree.xpath('/html/body/main/pre/a')
  for l in all_links:
    if l.attrib['href'].endswith("sources.jar"):
      # print(l.attrib['href'])
      jar_file = requests.get(link["link"] + "/" + l.attrib['href'])
      # print(link["link"] + "/" + l.attrib['href'])
      file_name = str(link["name"])+ "_" + str(link["year"]) + "_" + str(link["version"]) + ".jar"
      #print(file_name)
      with open(file_name ,'wb') as f:
        f.write(jar_file.content)
    
  #print(links)

# %%
# !tar -czvf ./content.tar /content/*
# Out:
# tar: Removing leading `/' from member names
# /content/aliyun-java-sdk-core_2015_2.0.0-rc1.jar
# /content/aliyun-java-sdk-core_2015_2.0.0-rc2.jar
# /content/aliyun-java-sdk-core_2015_2.0.2-rc1.jar
# /content/aliyun-java-sdk-core_2015_2.1.0.jar
# /content/aliyun-java-sdk-core_2015_2.1.1.jar
# /content/aliyun-java-sdk-core_2015_2.1.2.jar
# /content/aliyun-java-sdk-core_2015_2.1.3.jar
# /content/aliyun-java-sdk-core_2015_2.1.4.jar
# /content/aliyun-java-sdk-core_2015_2.1.5.jar
# /content/aliyun-java-sdk-core_2015_2.1.6.jar
# /content/aliyun-java-sdk-core_2015_2.1.7.jar
# /content/aliyun-java-sdk-core_2015_2.1.8.jar
# /content/aliyun-java-sdk-core_2015_2.1.9.jar
# /content/aliyun-java-sdk-core_2015_2.2.0.jar
# /content/aliyun-java-sdk-core_2015_2.2.1.jar
# /content/aliyun-java-sdk-core_2015_2.2.2.jar
# /content/aliyun-java-sdk-core_2015_2.2.3.jar
# /content/aliyun-java-sdk-core_2015_2.2.4.jar
# /content/aliyun-java-sdk-core_2015_2.2.5.jar
# /content/aliyun-java-sdk-core_2015_2.2.6.jar
# ...
